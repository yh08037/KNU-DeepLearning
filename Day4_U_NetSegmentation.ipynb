# %% [markdown]
# <a href="https://colab.research.google.com/github/yh08037/KNU-DeepLearning/blob/master/Day4_U_NetSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Skin lesion segmentation**
# - Delineate lesion boundary in skin images
# - Dataset - https://www.isic-archive.com/#!/topWithHeader/tightContentTop/challenges
# - Understanding how to build deeper networks for image segmentation
#
# Training set = 1000 skin images + label images (binary masks)
#
# 1.   Training set
#
#
# > 1000 skin images and label map (binary mask)
#
#
# 2.   Convolutional neural networks
#
# > Encoder-decoder segmentation network (Fully Convolutional Network)
#
#
# > U-Net: FCN with skip connection

# %%
# opencv 설치
# !pip install opencv-python

# 구글드라이브 파일 읽기 위한 연동 용 라이브러리
# !pip install -U -q PyDrive


from pydrive.auth import GoogleAuth

from pydrive.drive import GoogleDrive

from google.colab import auth

from oauth2client.client import GoogleCredentials 


# 1. Authenticate and create the PyDrive client.

auth.authenticate_user()

gauth = GoogleAuth()

gauth.credentials = GoogleCredentials.get_application_default()

drive = GoogleDrive(gauth)
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (3.4.5.20)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.14.6)

# %% [markdown]
# Training data link: https://drive.google.com/open?id=1rya9tkCuzm3F33L9ilT3RtLVUaDQsuOW

# %%
# 실질적으로 구글드라이브에서 파일을 불러오는 방법입니다.
# 위에서 준비해두었던 공유 가능한 링크에서 'id=' 이후에 있는 문자열을 복사하여 file_id로 사용합니다.
file_id = '1rya9tkCuzm3F33L9ilT3RtLVUaDQsuOW'
# file_id로부터 파일 객체를 생성합니다.
downloaded = drive.CreateFile({'id': file_id})
# 불러온 파일 객체를 Colab에 저장합니다.
downloaded.GetContentFile('training.zip')

# 압축해제
# !unzip training.zip
# 파일 확인
# !ls ./testing/image
# 파일 확인
# !ls ./testing/label
# Out:
# Archive:  training.zip
# replace testing/image/ISIC_0000000.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# ISIC_0000000.jpg  ISIC_0000054.jpg  ISIC_0000110.jpg  ISIC_0000165.jpg
# ISIC_0000001.jpg  ISIC_0000055.jpg  ISIC_0000111.jpg  ISIC_0000166.jpg
# ISIC_0000003.jpg  ISIC_0000056.jpg  ISIC_0000112.jpg  ISIC_0000167.jpg
# ISIC_0000004.jpg  ISIC_0000057.jpg  ISIC_0000113.jpg  ISIC_0000169.jpg
# ISIC_0000006.jpg  ISIC_0000058.jpg  ISIC_0000115.jpg  ISIC_0000170.jpg
# ISIC_0000007.jpg  ISIC_0000059.jpg  ISIC_0000116.jpg  ISIC_0000171.jpg
# ISIC_0000008.jpg  ISIC_0000060.jpg  ISIC_0000117.jpg  ISIC_0000172.jpg
# ISIC_0000009.jpg  ISIC_0000061.jpg  ISIC_0000119.jpg  ISIC_0000173.jpg
# ISIC_0000011.jpg  ISIC_0000062.jpg  ISIC_0000120.jpg  ISIC_0000175.jpg
# ISIC_0000012.jpg  ISIC_0000063.jpg  ISIC_0000121.jpg  ISIC_0000176.jpg
# ISIC_0000013.jpg  ISIC_0000064.jpg  ISIC_0000122.jpg  ISIC_0000177.jpg
# ISIC_0000014.jpg  ISIC_0000065.jpg  ISIC_0000123.jpg  ISIC_0000179.jpg
# ISIC_0000075_segmentation.jpg  ISIC_0000189_segmentation.jpg
# ISIC_0000077_segmentation.jpg  ISIC_0000190_segmentation.jpg
# ISIC_0000078_segmentation.jpg  ISIC_0000191_segmentation.jpg
# ISIC_0000079_segmentation.jpg  ISIC_0000192_segmentation.jpg
# ISIC_0000080_segmentation.jpg  ISIC_0000193_segmentation.jpg
# ISIC_0000081_segmentation.jpg  ISIC_0000196_segmentation.jpg
# ISIC_0000082_segmentation.jpg  ISIC_0000197_segmentation.jpg
# ISIC_0000085_segmentation.jpg  ISIC_0000198_segmentation.jpg
# ISIC_0000086_segmentation.jpg  ISIC_0000199_segmentation.jpg
# ISIC_0000087_segmentation.jpg  ISIC_0000200_segmentation.jpg
# ISIC_0000088_segmentation.jpg  ISIC_0000201_segmentation.jpg
# ISIC_0000089_segmentation.jpg  ISIC_0000202_segmentation.jpg
# ISIC_0000091_segmentation.jpg  ISIC_0000203_segmentation.jpg
# ISIC_0000092_segmentation.jpg  ISIC_0000204_segmentation.jpg
# ISIC_0000093_segmentation.jpg  ISIC_0000205_segmentation.jpg
# ISIC_0000094_segmentation.jpg  ISIC_0000206_segmentation.jpg
# ISIC_0000095_segmentation.jpg  ISIC_0000207_segmentation.jpg
# ISIC_0000096_segmentation.jpg  ISIC_0000208_segmentation.jpg
# ISIC_0000097_segmentation.jpg  ISIC_0000209_segmentation.jpg
# ISIC_0000098_segmentation.jpg  ISIC_0000210_segmentation.jpg
# ISIC_0000099_segmentation.jpg  ISIC_0000211_segmentation.jpg
# ISIC_0000100_segmentation.jpg  ISIC_0000212_segmentation.jpg
# ISIC_0000101_segmentation.jpg  ISIC_0000213_segmentation.jpg
# ISIC_0000102_segmentation.jpg  ISIC_0000214_segmentation.jpg
# ISIC_0000103_segmentation.jpg  ISIC_0000215_segmentation.jpg
# ISIC_0000104_segmentation.jpg  ISIC_0000216_segmentation.jpg
# ISIC_0000105_segmentation.jpg  ISIC_0000217_segmentation.jpg
# ISIC_0000107_segmentation.jpg  ISIC_0000218_segmentation.jpg
# ISIC_0000108_segmentation.jpg  ISIC_0000219_segmentation.jpg
# ISIC_0000109_segmentation.jpg  ISIC_0000220_segmentation.jpg

# %% [markdown]
# Image 와 Label 맵 불러오기

# %%
import os
import numpy as np
import glob
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


imgDir = './training/image/'
labelDir = './training/label/'

# 트레이닝 영상 리스트 얻기
imgList = glob.glob(imgDir + "/*.jpg")

for f in imgList:
  print(f)
  # 트레이닝 영상으로부터 id 얻기
  id = os.path.basename(f)
  id = os.path.splitext(id)[0]
  print(id)
  
  # label 영상 경로 
  labelF = labelDir + "/" + id + "_segmentation.jpg"  
  
  # 영상 로드
  img = mpimg.imread(f)
  plt.imshow(img)
  plt.axis("off")
  plt.show()
  
  label = mpimg.imread(labelF)
  plt.imshow(label)
  plt.axis("off")
  plt.show()
  
  break
# Out:
# ./training/image/ISIC_0010587.jpg
# ISIC_0010587

# %% [markdown]
# Keras를 이용한 Segmentation Network 구현

# %%
from keras.callbacks import ModelCheckpoint

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.activations import *
from keras.preprocessing.image import ImageDataGenerator
from keras.losses import *

import os
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import cv2

def bce_loss(y_true, y_pred):
    ''' Binary Cross Entropy

    Args:
        y_true (np.array): prediction
        y_pred (np.array): ground-truth
    '''
    return binary_crossentropy(y_true, y_pred)
  
def CNNArch(input_size, lr, depth=1):
    inputs = Input(input_size)

    outLayer = []
    # Encoder
    out = inputs
#     out = Dropout(0.8)(out)
    base = 64
    for d in range(depth):
      numFeatures = base * (d + 1)
      out = Conv2D(numFeatures, (3, 3), activation='relu', padding='same', kernel_initializer = 'he_normal')(out)
      out = Conv2D(numFeatures, (3, 3), activation='relu', padding='same', kernel_initializer = 'he_normal')(out)
      outLayer.append(out)
      out = MaxPooling2D(pool_size=(2, 2))(out)
      
    # bottom layer
    numFeatures = base * (depth + 1)
    out = Conv2D(numFeatures, (3, 3), activation='relu', padding='same', kernel_initializer = 'he_normal')(out)
    out = Conv2D(numFeatures, (3, 3), activation='relu', padding='same', kernel_initializer = 'he_normal')(out)
    
    # Decoder
    for d in range(depth):
        numFeatures = base * (depth - d)
        # Deconvolution (transposed convolution)
        out = Conv2DTranspose(numFeatures, (2, 2), strides=(2, 2), padding='same', kernel_initializer = 'he_normal')(out)
        prev = outLayer[depth-(d+1)]
        out = concatenate([out, prev], axis=-1)
        # Convolution
        out = Conv2D(numFeatures, (3, 3), activation='relu', padding='same', kernel_initializer = 'he_normal')(out)
        out = Conv2D(numFeatures, (3, 3), activation='relu', padding='same', kernel_initializer = 'he_normal')(out)
    
    out = Conv2D(base, (3, 3), activation='relu', padding='same', kernel_initializer = 'he_normal')(out)
    out = Conv2D(1, (1, 1), activation='sigmoid')(out)
    
    # Model 구축
    model = Model(inputs=[inputs], outputs=[out])
    model.compile(optimizer=Adam(lr=lr), loss=bce_loss, metrics=[bce_loss])
    model.summary()
    
    return model

# Label to binary
def adjust_data(image, label):
    image = image[0] / 255.0
    image = image[...,::-1]
    # label map 설정 (JPEG 포맷으로 binary mask이지만 정확한 1값이 아닐 수 있음)
    label = label[0][:,:,:,0]
#     print(np.max(label))
    label = np.expand_dims(label, axis=-1)
    label[label < 25] = 0
    label[label >= 25] = 1
    
    
    return image, label
  
# Keras Dataset 함수
def dataset(data_root, mask_root, target_size, batch_size):
    image_datagen = ImageDataGenerator()
    label_datagen = ImageDataGenerator()

    # Dataloader (image)
    image_generator = image_datagen.flow_from_directory(
        data_root,
        classes=['image'],
        target_size = target_size,
        batch_size=batch_size,
        seed=1)

    # Dataloader (label)
    label_generator = label_datagen.flow_from_directory(
        mask_root,
        classes=['label'],
        target_size = target_size,
        batch_size=batch_size,
        seed=1)

    data_generator = zip(image_generator, label_generator)
    for i, (image, label) in enumerate(data_generator):
        image, label = adjust_data(image, label)
        yield (image, label)
        
def save_result(output, data_root, predict_root, gt_root=None):
    img_path = []
    img_path += glob.glob(os.path.join(data_root, 'image/*.jpg'))
    img_path = sorted(img_path)

    label_path = []
    label_path += glob.glob(os.path.join(data_root, 'label/*.jpg'))
    label_path = sorted(label_path)

    output = output.squeeze()
    count = 0
    avgDice = 0
    for i in range(output.shape[0]):
        filename = img_path[i].split('/')[-1]
        predict_path = os.path.join(predict_root, filename)
        gt_path = os.path.join(gt_root, filename)

        img = mpimg.imread(img_path[i])
        label = mpimg.imread(label_path[i])
        target = cv2.imread(label_path[i])

        print(np.max(output[i]))
        print(np.min(output[i]))
        pred = np.round(output[i]) * 255.0 
        print(np.max(pred))
        print(np.min(pred))
        pred = np.expand_dims(pred, axis=2)
        zeros = np.zeros(pred.shape)
        pred = np.concatenate((zeros,zeros,pred), axis=2)
        
        pred = img + pred
        pred = (pred/(pred.max()+1e-6))*255.0
        pred = pred.astype(np.int)
        plt.imshow(pred)
        plt.axis("off")
        plt.show()
        count += 1
        
        #label adjust
        target = target[:,:,0]
        target[target < 25] = 0
        target[target >= 25] = 1
    
        intersect = np.round(output[i])
        intersect = np.count_nonzero(intersect[target==1])
        
        pred = output[i]
        entire = np.count_nonzero(pred[pred == 1]) + np.count_nonzero(label[target==1])        
        
        dice = intersect*2/entire
        avgDice = avgDice + dice
        
        if count == 10:
          print(avgDice/count)
          break
          
        
        
        
# Main 함수
if __name__ == "__main__":
  # 폴더 설정
  imgDir = './training/'
  labelDir = './training/'
  testImgDir = './testing/'
  testLabelDir = './testing/'
  outDir = './output/'
  
  # 모델 저장 위치
  if (not os.path.exists('./checkpoint')):
    os.mkdir('./checkpoint')
  train_ckpt_path = './checkpoint/unet.hdf5'
  test_ckpt_path = './checkpoint/trained/unet.hdf5'

  if (not os.path.exists(outDir)):
    os.mkdir(outDir)
  # 파라미터 설정
  input_size = (128,128,3)
  
  # Hyperparameters
  epoch = 20
  lr = 0.001
  train_batch_size = 30
  test_batch_size = 30
  depth =6
  
  # 트레이닝 데이터 셋 설정
  trainingSet = dataset(imgDir, labelDir, (128,128), train_batch_size)
  # 테스트 데이터 셋 설정
  testingSet = dataset(testImgDir, testLabelDir, (128,128),test_batch_size)
  
  # Model 구축
  model = CNNArch(input_size, lr, depth)
  
  # Checkpoint 셋팅
  model_checkpoint = ModelCheckpoint(train_ckpt_path,
                                    monitor='val_loss',
                                    verbose=2,
                                    save_best_only=True)
  # Model Train
  model.fit_generator(trainingSet,
                    steps_per_epoch=800/train_batch_size,
                    shuffle=True,
                    epochs=epoch,
                    validation_data=testingSet,
                    validation_steps=200/test_batch_size,
                    callbacks=[model_checkpoint],
                    workers=1)
  
  # Model Test
  results = model.predict_generator(testingSet,
                                    steps=1,
                                    verbose=1)
  save_result(results, testImgDir, outDir, testImgDir)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_26 (InputLayer)           (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv2d_337 (Conv2D)             (None, 128, 128, 64) 1792        input_26[0][0]
# __________________________________________________________________________________________________
# conv2d_338 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_337[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_76 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_338[0][0]
# __________________________________________________________________________________________________
# conv2d_339 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_340 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_339[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_77 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_340[0][0]
# __________________________________________________________________________________________________
# conv2d_341 (Conv2D)             (None, 32, 32, 192)  221376      max_pooling2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 32, 32, 192)  331968      conv2d_341[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_78 (MaxPooling2D) (None, 16, 16, 192)  0           conv2d_342[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 16, 16, 256)  442624      max_pooling2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 16, 16, 256)  590080      conv2d_343[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_79 (MaxPooling2D) (None, 8, 8, 256)    0           conv2d_344[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 8, 8, 320)    737600      max_pooling2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 8, 8, 320)    921920      conv2d_345[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_80 (MaxPooling2D) (None, 4, 4, 320)    0           conv2d_346[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 4, 4, 384)    1106304     max_pooling2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 4, 4, 384)    1327488     conv2d_347[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_81 (MaxPooling2D) (None, 2, 2, 384)    0           conv2d_348[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 2, 2, 448)    1548736     max_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 2, 2, 448)    1806784     conv2d_349[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_52 (Conv2DTran (None, 4, 4, 384)    688512      conv2d_350[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 4, 4, 768)    0           conv2d_transpose_52[0][0]
#                                                                  conv2d_348[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 4, 4, 384)    2654592     concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 4, 4, 384)    1327488     conv2d_351[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_53 (Conv2DTran (None, 8, 8, 320)    491840      conv2d_352[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 640)    0           conv2d_transpose_53[0][0]
#                                                                  conv2d_346[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 8, 8, 320)    1843520     concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 8, 8, 320)    921920      conv2d_353[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_54 (Conv2DTran (None, 16, 16, 256)  327936      conv2d_354[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 16, 16, 512)  0           conv2d_transpose_54[0][0]
#                                                                  conv2d_344[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 16, 16, 256)  1179904     concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 16, 16, 256)  590080      conv2d_355[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_55 (Conv2DTran (None, 32, 32, 192)  196800      conv2d_356[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 32, 32, 384)  0           conv2d_transpose_55[0][0]
#                                                                  conv2d_342[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 32, 32, 192)  663744      concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 32, 32, 192)  331968      conv2d_357[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_56 (Conv2DTran (None, 64, 64, 128)  98432       conv2d_358[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 64, 64, 256)  0           conv2d_transpose_56[0][0]
#                                                                  conv2d_340[0][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, 64, 64, 128)  295040      concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_359[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_57 (Conv2DTran (None, 128, 128, 64) 32832       conv2d_360[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_57[0][0]
#                                                                  conv2d_338[0][0]
# __________________________________________________________________________________________________
# conv2d_361 (Conv2D)             (None, 128, 128, 64) 73792       concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_362 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_361[0][0]
# __________________________________________________________________________________________________
# conv2d_363 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_362[0][0]
# __________________________________________________________________________________________________
# conv2d_364 (Conv2D)             (None, 128, 128, 1)  65          conv2d_363[0][0]
# ==================================================================================================
# Total params: 21,234,945
# Trainable params: 21,234,945
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/20
# Found 200 images belonging to 1 classes.
# Found 800 images belonging to 1 classes.
# Found 200 images belonging to 1 classes.
# Found 800 images belonging to 1 classes.
# 27/26 [==============================] - 41s 2s/step - loss: 0.5995 - bce_loss: 0.5995 - val_loss: 0.5249 - val_bce_loss: 0.5249
#
# Epoch 00001: val_loss improved from inf to 0.52490, saving model to ./checkpoint/unet.hdf5
# Epoch 2/20
# 27/26 [==============================] - 20s 747ms/step - loss: 0.4369 - bce_loss: 0.4369 - val_loss: 0.4806 - val_bce_loss: 0.4806
#
# Epoch 00002: val_loss improved from 0.52490 to 0.48055, saving model to ./checkpoint/unet.hdf5
# Epoch 3/20
# 27/26 [==============================] - 20s 744ms/step - loss: 0.3869 - bce_loss: 0.3869 - val_loss: 0.3429 - val_bce_loss: 0.3429
#
# Epoch 00003: val_loss improved from 0.48055 to 0.34290, saving model to ./checkpoint/unet.hdf5
# Epoch 4/20
# 27/26 [==============================] - 20s 745ms/step - loss: 0.3771 - bce_loss: 0.3771 - val_loss: 0.4485 - val_bce_loss: 0.4485
#
# Epoch 00004: val_loss did not improve from 0.34290
# Epoch 5/20
# 27/26 [==============================] - 20s 744ms/step - loss: 0.3453 - bce_loss: 0.3453 - val_loss: 0.3570 - val_bce_loss: 0.3570
#
# Epoch 00005: val_loss did not improve from 0.34290
# Epoch 6/20
# 27/26 [==============================] - 20s 745ms/step - loss: 0.2916 - bce_loss: 0.2916 - val_loss: 0.3002 - val_bce_loss: 0.3002
#
# Epoch 00006: val_loss improved from 0.34290 to 0.30021, saving model to ./checkpoint/unet.hdf5
# Epoch 7/20
# 27/26 [==============================] - 20s 745ms/step - loss: 0.2834 - bce_loss: 0.2834 - val_loss: 0.3212 - val_bce_loss: 0.3212
#
# Epoch 00007: val_loss did not improve from 0.30021
# Epoch 8/20
# 27/26 [==============================] - 20s 745ms/step - loss: 0.2979 - bce_loss: 0.2979 - val_loss: 0.3254 - val_bce_loss: 0.3254
#
# Epoch 00008: val_loss did not improve from 0.30021
# Epoch 9/20
# 27/26 [==============================] - 20s 743ms/step - loss: 0.2573 - bce_loss: 0.2573 - val_loss: 0.3364 - val_bce_loss: 0.3364
#
# Epoch 00009: val_loss did not improve from 0.30021
# Epoch 10/20
# 27/26 [==============================] - 20s 743ms/step - loss: 0.2425 - bce_loss: 0.2425 - val_loss: 0.3793 - val_bce_loss: 0.3793
#
# Epoch 00010: val_loss did not improve from 0.30021
# Epoch 11/20
# 27/26 [==============================] - 20s 744ms/step - loss: 0.2412 - bce_loss: 0.2412 - val_loss: 0.2897 - val_bce_loss: 0.2897
#
# Epoch 00011: val_loss improved from 0.30021 to 0.28966, saving model to ./checkpoint/unet.hdf5
# Epoch 12/20
# 27/26 [==============================] - 20s 745ms/step - loss: 0.2043 - bce_loss: 0.2043 - val_loss: 0.3440 - val_bce_loss: 0.3440
#
# Epoch 00012: val_loss did not improve from 0.28966
# Epoch 13/20
# 27/26 [==============================] - 20s 743ms/step - loss: 0.1923 - bce_loss: 0.1923 - val_loss: 0.2802 - val_bce_loss: 0.2802
#
# Epoch 00013: val_loss improved from 0.28966 to 0.28019, saving model to ./checkpoint/unet.hdf5
# Epoch 14/20
# 27/26 [==============================] - 20s 742ms/step - loss: 0.1711 - bce_loss: 0.1711 - val_loss: 0.2964 - val_bce_loss: 0.2964
#
# Epoch 00014: val_loss did not improve from 0.28019
# Epoch 15/20
# 27/26 [==============================] - 20s 744ms/step - loss: 0.1492 - bce_loss: 0.1492 - val_loss: 0.3068 - val_bce_loss: 0.3068
#
# Epoch 00015: val_loss did not improve from 0.28019
# Epoch 16/20
# 27/26 [==============================] - 20s 744ms/step - loss: 0.1516 - bce_loss: 0.1516 - val_loss: 0.3093 - val_bce_loss: 0.3093
#
# Epoch 00016: val_loss did not improve from 0.28019
# Epoch 17/20
# 27/26 [==============================] - 20s 745ms/step - loss: 0.1300 - bce_loss: 0.1300 - val_loss: 0.2579 - val_bce_loss: 0.2579
#
# Epoch 00017: val_loss improved from 0.28019 to 0.25792, saving model to ./checkpoint/unet.hdf5
# Epoch 18/20
# 27/26 [==============================] - 20s 744ms/step - loss: 0.3093 - bce_loss: 0.3093 - val_loss: 0.3496 - val_bce_loss: 0.3496
#
# Epoch 00018: val_loss did not improve from 0.25792
# Epoch 19/20
# 27/26 [==============================] - 20s 745ms/step - loss: 0.2832 - bce_loss: 0.2832 - val_loss: 0.2506 - val_bce_loss: 0.2506
#
# Epoch 00019: val_loss improved from 0.25792 to 0.25059, saving model to ./checkpoint/unet.hdf5
# Epoch 20/20
#  9/26 [=========>....................] - ETA: 12s - loss: 0.1916 - bce_loss: 0.1916
